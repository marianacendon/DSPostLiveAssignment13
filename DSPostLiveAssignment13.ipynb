# %%
my_list = [45.4, 44.2, 36.8, 35.1, 39.0, 60.0, 47.4, 41.1, 45.8, 35.6]
print my_list[5]
# Out:
# 60.0

# %%
my_list.append(55.2)

# %%
print my_list
# Out:
# [45.4, 44.2, 36.8, 35.1, 39.0, 60.0, 47.4, 41.1, 45.8, 35.6, 55.2]

# %%
list_del = my_list.pop(6)

# %%
print my_list
# Out:
# [45.4, 44.2, 36.8, 35.1, 39.0, 60.0, 41.1, 45.8, 35.6, 55.2]

# %%
for value in my_list:
    if value > 45:
         print(value)
# Out:
# 45.4
# 60.0
# 45.8
# 55.2

# %%
import numpy as np

# %%
mylist_array = np.array([45.4, 44.2, 36.8, 35.1, 39.0, 60.0, 47.4, 41.1, 45.8, 35.6])
print mylist_array 
print np.mean(mylist_array)
print mylist_array > 45
print np.max(mylist_array)
print np.min(mylist_array)
# Out:
# [ 45.4  44.2  36.8  35.1  39.   60.   47.4  41.1  45.8  35.6]
# 43.04
# [ True False False False False  True  True False  True False]
# 60.0
# 35.1

# %%
import pandas as pd
#from pandas import DataFrame, read_csv
iris = pd.read_csv('~/Desktop/DataScience/PostLiveAssignments/DSPostlive13/iris.csv')
print iris
#Using iris.head(), display the head of the dataset
iris.head()
iris.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %%
#Use DataFrame.drop() to drop the id column
iris.drop('Id', axis = 1, inplace=True)
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#Subset dataframe to create a new data frame that includes only the measurements for the setosa species
irisetosa = iris[iris.Species == 'Iris-setosa']

# %%
#Use DataFrame.describe() to get the summary statistics
irisetosa.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count       50.00000     50.000000      50.000000      50.00000
# mean         5.00600      3.418000       1.464000       0.24400
# std          0.35249      0.381024       0.173511       0.10721
# min          4.30000      2.300000       1.000000       0.10000
# 25%          4.80000      3.125000       1.400000       0.20000
# 50%          5.00000      3.400000       1.500000       0.20000
# 75%          5.20000      3.675000       1.575000       0.30000
# max          5.80000      4.400000       1.900000       0.60000

# %%
#Use DataFrame.groupby() to create grouped data frames by Species and compute summary statistics using DataFrame.describe()
irisetosa.groupby(irisetosa['Species']).describe()
iris.groupby(iris['Species']).describe()
# Out:
#                        PetalLengthCm  PetalWidthCm  SepalLengthCm  \
# Species
# Iris-setosa     count      50.000000     50.000000      50.000000
#                 mean        1.464000      0.244000       5.006000
#                 std         0.173511      0.107210       0.352490
#                 min         1.000000      0.100000       4.300000
#                 25%         1.400000      0.200000       4.800000
#                 50%         1.500000      0.200000       5.000000
#                 75%         1.575000      0.300000       5.200000
#                 max         1.900000      0.600000       5.800000
# Iris-versicolor count      50.000000     50.000000      50.000000
#                 mean        4.260000      1.326000       5.936000
#                 std         0.469911      0.197753       0.516171
#                 min         3.000000      1.000000       4.900000
#                 25%         4.000000      1.200000       5.600000
# ...

# %%
# %matplotlib inline

# %%
#Use DataFrame.boxplot() to plot boxplots by Species
iris.boxplot(column=None, by='Species')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x119ac4850>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d480090>]], dtype=object)

# %%
# %matplotlib inline

# %%
#Plot a scatter matrix plot using the seaborn library. Use the following to load and plot 
import seaborn as sns
sns.pairplot(iris,hue='Species')

# %%
# %matplotlib inline

# %%
sns.pairplot(iris)
